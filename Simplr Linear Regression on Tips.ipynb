# %%
# Import All Libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Load the data into a Pandas DataFrame
data = pd.read_excel('Tips.xlsx')

# Check the first few rows
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  Unnamed: 7  Unnamed: 8  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2         NaN         NaN
# 1       10.34  1.66    Male     No  Sun  Dinner     3         NaN         NaN
# 2       21.01  3.50    Male     No  Sun  Dinner     3         NaN         NaN
# 3       23.68  3.31    Male     No  Sun  Dinner     2         NaN         NaN
# 4       24.59  3.61  Female     No  Sun  Dinner     4         NaN         NaN
#
#    Unnamed: 9  ...  Unnamed: 492  Unnamed: 493  Unnamed: 494  \
# 0         NaN  ...           NaN           NaN           NaN
# 1         NaN  ...           NaN           NaN           NaN
# 2         NaN  ...           NaN           NaN           NaN
# 3         NaN  ...           NaN           NaN           NaN
# 4         NaN  ...           NaN           NaN           NaN
#
#           Unnamed: 495  Unnamed: 496  Unnamed: 497  Unnamed: 498  \
# 0                10.34          1.66          Male            No
# 1  2021-01-01 00:00:00          3.50          Male            No
# 2                23.68          3.31          Male            No
# 3                24.59          3.61        Female            No
# 4                25.29          4.71          Male            No
#
#    Unnamed: 499  Unnamed: 500  Unnamed: 501
# 0           Sun        Dinner           3.0
# 1           Sun        Dinner           3.0
# 2           Sun        Dinner           2.0
# 3           Sun        Dinner           4.0
# 4           Sun        Dinner           4.0
#
# [5 rows x 502 columns]

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# total_bill      0
# tip             0
# sex             0
# smoker          0
# day             0
#                ..
# Unnamed: 497    1
# Unnamed: 498    1
# Unnamed: 499    1
# Unnamed: 500    1
# Unnamed: 501    1
# Length: 502, dtype: int64

# %%
# Identify columns to drop
columns_to_drop = [col for col in data.columns if 'Unnamed' in col]

# Drop the identified columns
data = data.drop(columns_to_drop, axis=1)

# Print the cleaned dataset
data.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Visualize the relationship between total bill and tip
sns.scatterplot(x='total_bill', y='tip', data=data)
plt.show()

# %%
# Assuming you cleaned the data in a separate step
X = data[['total_bill']]  # Update the feature matrix if necessary
y = data['tip']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the testing set
y_pred = model.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print('Mean Squared Error:', mse)
print('R-squared:', r2)
# Out:
# Mean Squared Error: 0.7524510349809156
# R-squared: 0.4291782688312412

# %%
model.predict([[28.40]])
# Out:
# c:\Users\HP\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.96953898])
